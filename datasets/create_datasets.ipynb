# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('tweets.csv', encoding='ISO-8859-1', error_bad_lines=False, header=None)
data.describe()
# Out:
#                   0             1
# count  1.600000e+06  1.600000e+06
# mean   2.000000e+00  1.998818e+09
# std    2.000001e+00  1.935761e+08
# min    0.000000e+00  1.467810e+09
# 25%    0.000000e+00  1.956916e+09
# 50%    2.000000e+00  2.002102e+09
# 75%    4.000000e+00  2.177059e+09
# max    4.000000e+00  2.329206e+09

# %%
data = data.drop(columns=[1, 2, 3, 4])

# %%
data.columns=['sentiment', 'text']
data.head()
# Out:
#    sentiment                                               text
# 0          0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          0  is upset that he can't update his Facebook by ...
# 2          0  @Kenichan I dived many times for the ball. Man...
# 3          0    my whole body feels itchy and like its on fire
# 4          0  @nationwideclass no, it's not behaving at all....

# %%
data.sentiment = np.where(data.sentiment == 4, 1, 0)
data.sample(10)
# Out:
#          sentiment                                               text
# 550914           0      I haven't posted in 3 months!!! I'm slacking
# 1328557          1  re-reading @cliffordheath presentation on Tree...
# 890295           1  @danielledeleasa Coming from the church, equal...
# 1023389          1  @RemoveMyFatSuit wow well done you! I am so im...
# 1309081          1  @jeremarketer it joy to be a part of something...
# 1311454          1                       Going to bed...sweet dreams
# 781324           0                    Starting the day knackered...
# 1544032          1  My piss looks like it glows in the dark. It's ...
# 61398            0  My bottle of patron broke in my suitecase  now...
# 8556             0  @heatheranne Thanks for the follow. Can't wait...

# %%
data = data.drop_duplicates('text')
data.describe()
# Out:
#           sentiment
# count  1.581466e+06
# mean   5.003465e-01
# std    5.000000e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00

# %%
train, test = train_test_split(data, test_size=0.4, random_state=1000, shuffle=True)

# %%
train.to_csv('train.csv', index=False)
train.describe()
# Out:
#            sentiment
# count  948879.000000
# mean        0.501008
# std         0.499999
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
test.to_csv('test.csv', index=False)
test.describe()
# Out:
#            sentiment
# count  632587.000000
# mean        0.499354
# std         0.500000
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
